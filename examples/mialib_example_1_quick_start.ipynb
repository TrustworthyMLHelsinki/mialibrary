# %% [markdown]
# ## Quick start
#
# ### With Command Line
#
# If you want to run in command line, try:
# ```
# python -m mialibrary.lira.process_fast_lira --data_path /path/to/data --use_median --fix_variance
# ```
# Ensure you have the required statistics and in_indices files in the `data_path`, starting with `stat_*`, `in_indices_*`.

# %% [markdown]
# ### In Jupyter Notebook

# %%
# Import the library
from mialibrary.lira.process_fast_lira import process_lira_data

# %%
# Define path to your data
data_path = "data_small"

# Compute LiRA scores
process_lira_data(
    data_path=data_path,
    filter_pattern="*",  # Adjust filter pattern as needed
    fix_variance=True,    # Example: Fix variance in computation
    use_median=True       # Example: Use median in computation
)
# Out:
# Found 1 stats files
# Already processed: 0, to process: 1
# Processing: data_small/scores_small_patch_camelyon_vit-b-16_-1_16384_-1.0_22_22.pkl
# Data loaded successfully.
# Median & Global
# Time to compute scores: 0.65 seconds
# Scores computed and saved successfully to data_small/scores_small_patch_camelyon_vit-b-16_-1_16384_-1.0_22_22.pkl.
